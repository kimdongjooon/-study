# %% [markdown]
# ## 4.6.8 행렬과 연립 방정식

# %% [markdown]
# ## 4.6.9 행렬과 사상
#
# 행렬은 '벡터를 다른 벡터로 변환하는 규칙'으로 해석할 수 있습니다.

# %% [markdown]
# # 4.7 지수 함수와 로그 함수

# %% [markdown]
# ## 4.7.1 지수
#
# 지수는 '그 수를 여러 번 곱한다'는 곱셈의 횟수에서 출발한 개녑이다.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(-4,4,100)

y = 2**x
y2 = 3**x
y3 = 0.5**x

plt.figure(figsize=(5,5))
plt.plot(x,y, 'black', linewidth=3, label='$y=2^x$')
plt.plot(x,y2, 'cornflowerblue', linewidth=3, label='$y=3^x$')
plt.plot(x,y3, 'gray',linewidth=3, label='$y=0.5^x$')
plt.ylim(-2,6)
plt.xlim(-4,4)
plt.grid(True)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## 4.7.2 로그

# %%
# 그림 4-29
x = np.linspace(-8,8,100)
y = 2**x

x2 = np.linspace(0.001,8,100) # 0은 로그에서 에러나 남.
y2 = np.log(x2)/ np.log(2)
plt.plot(x,y,'black', linewidth=3)
plt.plot(x2,y2, 'cyan', linewidth=3)
plt.plot(x,x,'black', linestyle='--', linewidth=1)
plt.ylim(-8,8)
plt.xlim(-8,8)
plt.grid(True)
plt.show()

# %%
# 그림 4-30
x = np.linspace(-4,4,100)
y = (x - 1)**2 +2
logy = np.log(y)

plt.figure(figsize = (4,4))
plt.plot(x,y,'black', linewidth=3)
plt.plot(x,logy,'cyan', linewidth=3)
plt.yticks(range(-4,9,1))
plt.xticks(range(-4,5,1))
plt.ylim(-4,8)
plt.xlim(-4,4)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4.7.3 지수 함수의 미분

# %%
x = np.linspace(-4, 4, 100) 
a = 2 # 이 값을 여러 가지로 바꿔보자
y = a**x 
dy = np.log(a) * y 
plt.figure(figsize=(4, 4)) 
plt.plot(x, y, 'gray', linestyle='--', linewidth=3) 
plt.plot(x, dy, color='black', linewidth=3) 
plt.ylim(-1, 8) 
plt.xlim(-4, 4)
plt.grid(True) 
plt.show()

# %% [markdown]
# ## 4.7.4 로그 함수의 미분

# %%
x = np.linspace(0.0001, 4, 100) # 0 이하로 정의할 수 없는 
y = np.log(x) 
dy = 1 / x 
plt.figure(figsize=(4, 4)) 
plt.plot(x, y, 'gray', linestyle='--', linewidth=3) 
plt.plot(x, dy, color='black', linewidth=3) 
plt.ylim(-8, 8) 
plt.xlim(-1, 4) 
plt.grid(True) 
plt.show()

# %% [markdown]
# ## 4.7.5 시그모이드 함수
#
# 매끄러운 계단 모양 함수

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
x = np.linspace(-10,10,100)
#y = 1+np.exp(-x)
#y = -np.log(1/x-1)
y = 1/ (1 + np.exp(-x))

plt.figure(figsize=(4,4))
plt.plot(x,y,'cyan', linewidth=3)

plt.ylim(-1,2)
plt.xlim(-10,10)
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4.7.6 소프트맥스 함수

# %%
def softmax(x0, x1, x2): 
  u = np.exp(x0) + np.exp(x1) + np.exp(x2)
  return np.exp(x0) / u, np.exp(x1) / u, np.exp(x2) / u 

y = softmax(2, 1, -1) 
print(np.round (y, 2)) # (A) 소수점 2 자리로 최대한 가깝게 표시 
print(np.sum (y)) # (B) 합계를 표시
# Out:
# [0.71 0.26 0.04]
# 1.0

# %%
from mpl_toolkits.mplot3d import Axes3D
xn = 20
x0 = np.linspace(-4, 4, xn)
x1 = np.linspace(-4, 4, xn)

y = np.zeros((xn, xn, 3))
for i0 in range(xn): 
  for i1 in range(xn): 
    y[i1, i0, :] = softmax(x0[i0], x1[i1], 1)
    
xx0, xx1 = np.meshgrid(x0, x1) 
plt.figure(figsize=(8, 3)) 
for i in range(2): 
  ax = plt.subplot(1, 2, i + 1, projection='3d') 
  ax.plot_surface(xx0, xx1, y[:, :, i],
                  rstride=1, cstride=1, alpha=0.3,
                  color='blue', edgecolor='black') 
  ax.set_xlabel('$x_0$', fontsize=14) 
  ax.set_ylabel('$x_1$', fontsize=14) 
  ax.view_init(40, -125)
  
  
plt.show()

# %% [markdown]
# ## 소프트맥스 함수와 시그모이드 함수
#
# 시그모이드 함수를 다변수로 확장한 것이 스프트맥스 함구라고 할 수 있다.

# %% [markdown]
# ## 4.7.8 가우스 함수

# %%
def gauss(mu,sigma,a):
  return a * np.exp(-(x-mu)**2/ sigma**2)

x = np.linspace(-4, 4, 100)
plt.figure(figsize=(4, 4)) 
plt.plot(x, gauss(0, 1, 1), 'black', linewidth=3) 
plt.plot(x, gauss(2, 3, 0.5), 'gray', linewidth=3) 
plt.ylim(-.5, 1.5) 
plt.xlim(-4, 4) 
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4.7.9 2차원 가우스 함수

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import axes3d 
# %matplotlib inline

def gauss(x,mu,sigma):
  N,D = x.shape
  c1 = 1 / (2 * np.pi)**(D / 2) 
  c2 = 1 / (np.linalg.det(sigma)**(1/2)) 
  inv_sigma = np.linalg.inv(sigma) 
  c3 = x - mu 
  c4 = np.dot(c3, inv_sigma) 
  c5 = np.zeros(N) 
  for d in range(D):
    c5 = c5+ c4[:, d] * c3[:, d] 
    p = c1 * c2 * np.exp(-c5 / 2) 
    return p

# %%
x = np.array([[1, 2], [2, 1], [3, 4]]) 
mu = np.array([1, 2]) 
sigma = np.array([[1, 0], [0, 1]]) 
print(gauss(x, mu, sigma))
# Out:
# [0.15915494 0.09653235 0.02153928]
